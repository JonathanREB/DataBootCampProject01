# %%
import numpy as np
import pandas as pd


df_retail = pd.read_csv('input/ventas_retail.csv')


df_retail.head()
# Out:
#              Canal    Cadena MEDIA         ID   Datos    Categoria  \
# 0  Departamentales  Sanborns    NaN        0.0  Desp U      Cocina
# 1  Departamentales  Sanborns    NaN   203883.0  Desp U     Belleza
# 2  Departamentales  Sanborns    NaN  6950613.0  Desp U     Belleza
# 3  Departamentales  Sanborns    NaN  1203011.0  Desp U  Ferreteria
# 4  Departamentales  Sanborns    NaN   900737.0  Desp U      Cocina
#
#              Marca            Submarca           UPC  \
# 0     FLAVOR STONE  JUEGO DE CUCHILLOS  8.308090e+11
# 1    FLAWLESS LEGS       FLAWLESS LEGS  7.545020e+11
# 2  MICROTOUCH SOLO     MICROTOUCH SOLO  7.545020e+11
# 3      TURBOTHRUST         TURBOTHRUST  6.448120e+11
# 4          Cerafit      CERAFIT FUSION  8.308090e+11
#
#                                Descripcion Jan-19
# 0  JUEGO DE CUCHILLOS FLAVOR STONE  AZULES     -
# 1                            FLAWLESS LEGS     5
# 2                          MICROTOUCH SOLO    57
# ...

# %%
info_retail = ['Cadena', 'Categoria', 'Marca',
     'UPC', 'Descripcion']
df_retail = df_retail[info_retail]
df_retail.head()
# Out:
#      Cadena   Categoria            Marca           UPC  \
# 0  Sanborns      Cocina     FLAVOR STONE  8.308090e+11
# 1  Sanborns     Belleza    FLAWLESS LEGS  7.545020e+11
# 2  Sanborns     Belleza  MICROTOUCH SOLO  7.545020e+11
# 3  Sanborns  Ferreteria      TURBOTHRUST  6.448120e+11
# 4  Sanborns      Cocina          Cerafit  8.308090e+11
#
#                                Descripcion
# 0  JUEGO DE CUCHILLOS FLAVOR STONE  AZULES
# 1                            FLAWLESS LEGS
# 2                          MICROTOUCH SOLO
# 3                              TURBOTHRUST
# 4                           CERAFIT FUSION
